# %%
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup
import colorama
import regex as re

# %% [markdown]
# Scraping code from https://github.com/x4nth055/pythoncode-tutorials/tree/master/web-scraping/link-extractor adapted for our use.

# %%
# init the colorama module
colorama.init()
GREEN = colorama.Fore.GREEN
GRAY = colorama.Fore.LIGHTBLACK_EX
RESET = colorama.Fore.RESET

# %%
# initialize the set of links (unique links)
internal_urls = set()
external_urls = set()

# %%
def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

# %%
def get_all_website_links(url):
    """
    Returns all URLs that is found on `url` in which it belongs to the same website
    """
    # all URLs of `url`
    urls = set()
    # domain name of the URL without the protocol
    domain_name = urlparse(url).netloc
    
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            # href empty tag
            continue
    
        # join the URL if it's relative (not absolute link)
        href = urljoin(url, href)

        parsed_href = urlparse(href)
        # remove URL GET parameters, URL fragments, etc.
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path

        if not is_valid(href):
            # not a valid URL
            continue
        if href in internal_urls:
            # already in the set
            continue
        if domain_name not in href:
            # external link
            if href not in external_urls:
                print(f"{GRAY}[!] External link: {href}{RESET}")
                external_urls.add(href)
            continue

        print(f"{GREEN}[*] Internal link: {href}{RESET}")
        urls.add(href)
        internal_urls.add(href)
    
    return urls

# %%
# number of urls visited so far will be stored here
total_urls_visited = 0

def crawl(url, max_urls=1000):
    """
    Crawls a web page and extracts all links.
    You'll find all links in `external_urls` and `internal_urls` global set variables.
    params:
        max_urls (int): number of max urls to crawl, default is 30.
    """
    global total_urls_visited
    total_urls_visited += 1
    links = get_all_website_links(url)
    for link in links:
        if total_urls_visited > max_urls:
            break
        crawl(link, max_urls=max_urls)

# %%
# we want the links from here, since it's only piano music
url = 'https://www.vgmusic.com/music/other/miscellaneous/piano/'

# %%
crawl(url)
# Out:
# [*] Internal link: http://www.vgmusic.com/information/donate.php
# [*] Internal link: https://www.vgmusic.com/
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/dotHack_Loop2.mid
# [*] Internal link: https://www.vgmusic.com/file/c5303ca449b42c033b965d782f79d036.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/WorldRunner.mid
# [*] Internal link: https://www.vgmusic.com/file/3e40cbc8bd18cdbe1cce637191b2ad4c.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/7Church.mid
# [*] Internal link: https://www.vgmusic.com/file/2da0227c706a81b91762026c6c6d704e.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/act_raiser-north_wall.mid
# [*] Internal link: https://www.vgmusic.com/file/6e11c438b213173c01613169efacdd36.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/EAGLE.mid
# [*] Internal link: https://www.vgmusic.com/file/25c23423d7964cec931a97fe12a2b41b.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/dino_riki_1.mid
# [*] Internal link: https://www.vgmusic.com/file/26c6aa47e10dd177ed52e84fbd93deb7.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Aion_Death_Waltz.mid
# [*] Internal link: https://www.vgmusic.com/file/09c8f22773df88ae63833998955468d5.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Aion_Fairy_Of_The_Peace.mid
# [*] Internal link: https://www.vgmusic.com/file/0700766a07f78548ffa76de397e34850.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Aion
html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/RedKnight.mid
# [*] Internal link: https://www.vgmusic.com/file/7395685a2351fcc70f2ac2c8abbaff2b.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/BrokenShards.mid
# [*] Internal link: https://www.vgmusic.com/file/4a05263b33e1a1631fd40b4ed0f39021.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/ShipofRegretandSleep.mid
# [*] Internal link: https://www.vgmusic.com/file/d4b334ace534f22773b3d4aba928a65c.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/TearoftheStars.mid
# [*] Internal link: https://www.vgmusic.com/file/cb5263d801af4a50b4425364c65b9230.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/TheWoundedShallAdvanceIntoTheLight.mid
# [*] Internal link: https://www.vgmusic.com/file/7425b070937084f1ae7b1df698ca4081.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/StolenTreasure.mid
# [*] Internal link: https://www.vgmusic.com/file/4bcefe29b14e15bdae2f6a98c541d72f.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/TjsS2OP.mid
# [*] Internal link: https://www.vgmusic.com/file/7b8be4964bd8b57e7ca848702af9bbd7.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/ValleyWhereTheWindIsBorn.mid
# [*] Internal link: https://www.vgmusic.com/file/cd487a5e6d2eacf7f0bb6be300494bc0.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/KokoroPianoVersion.mid
# [*] Internal link: https://www.vgmusic.com/file/78182b4ea627edc731be0e9e677af19f.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/YMED.mid
# [*] Internal link: https://www.vgmusic.com/file/3cd0aaa460014d46ea813ab94da60503.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/yoshi17.mid
# [*] Internal link: https://www.vgmusic.com/file/3d14a70307f2b54a4d339160be0a555b.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/mys-01.mid
# [*] Internal link: https://www.vgmusic.com/file/f981302bba8c3db337b29ceeaaf5f2fc.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/yswars.mid
# [*] Internal link: https://www.vgmusic.com/file/7838a7e49154f7bf237157d62c629be2.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/adventures_of_link-house.mid
# [*] Internal link: https://www.vgmusic.com/file/1295c6c305823a9b8b6b8ec7f2685c92.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/adventures_of_link-main_theme.mid
# [*] Internal link: https://www.vgmusic.com/file/44cfe1061358d08f4510db2b93e0f1c9.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Zelda2_Palace.mid
# [*] Internal link: https://www.vgmusic.com/file/46288a4e1ac1e7be6b6e564f041c56e8.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Zelda.mid
# [*] Internal link: https://www.vgmusic.com/file/922cded15671a099a005f27547007b9e.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Dr_Toungues_Castle.mid
# [*] Internal link: https://www.vgmusic.com/file/96571c1efccc6d92e9e293cf63f1e402.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Pyramid_of_Fear.mid
# [*] Internal link: https://www.vgmusic.com/file/3b86effc3704d4479830e673efb5c94a.html
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Zombie_Panic.mid
# [*] Internal link: https://www.vgmusic.com/file/3a48d18ca2633c65431924675c8ca316.html
# [*] Internal link: http://www.vgmusic.com/
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [!] External link: http://disqus.com/
# [!] External link: https://disqus.com
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [*] Internal link: https://www.vgmusic.com/music/other/miscellaneous/piano/Europe(piano).mid
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
links = [i for i in internal_urls if i[-3:] == 'mid']

# %%
def getFileName(link):
    link.split('/')[::-1][0]
    
    return filename

def download_midi(url):
    filename = url.split('/')[::-1][0]
    mid_file = requests.get(url, stream=True)
    with open('..\\..\\data\\videogame_midi\\' + filename, 'wb') as saveMidFile:
        saveMidFile.write(mid_file.content)
        print('Downloaded {} successfully.'.format(filename))

# %%
for link in links:
    download_midi(link)
# Out:
# Downloaded Rock_the_Mic_-_piano.mid successfully.
# Downloaded MNG-tosasolo.mid successfully.
# Downloaded BKendsolo.mid successfully.
# Downloaded BT_Character_Parade_Piano.mid successfully.
# Downloaded ValleyWhereTheWindIsBorn.mid successfully.
# Downloaded darkearthsolo.mid successfully.
# Downloaded lurk_in_dark.mid successfully.
# Downloaded oh_light.mid successfully.
# Downloaded tomahawk.mid successfully.
# Downloaded BlueStone_Zelda_Church.mid successfully.
# Downloaded Rachel_Piano_tempofix.mid successfully.
# Downloaded Thosechosenby_the_planet.mid successfully.
# Downloaded DDRSo_Deep_Piano.mid successfully.
# Downloaded Hit_the_Targets.mid successfully.
# Downloaded CurseoftheDeadShips-HowardDrossin.mid successfully.
# Downloaded FF3_Battle_%28Piano%29.mid successfully.
# Downloaded Kalimari_Desert_MK64.mid successfully.
# Downloaded Overture_WIP.mid successfully.
# Downloaded 07bubbleman.mid successfully.
# Downloaded surf-1.mid successfully.
# Downloaded festivalsolo.mid successfully.
# Downloaded ff9-battle-piano.mid successfully.
# Downloaded Hyrule_Castle_LTTP_Piano.mid successfully.
# Downloaded AT.mid successfully.
# Downloaded verdanturf.mid successfully.
# Downloaded Aion_Fairy_Of_The_Peace.mid successfully.
# Downloaded Gyromite-piano_only.mid successfully.
# Downloaded PokemonLeagueDay.mid successfully.
# Downloaded StarFoxAdventures_DarkIceMines_PianoRemix.mid successfully.
# Downloaded 6.mid successfully.
# Downloaded poktcg-elitesolo.mid successfully.
# Downloaded holy_intruder.mid successfully.
# Downloaded topman.mid successfully.
# Downloaded BlueStone_AGentleWindBlows.mid successfully.
# Downloaded lom_heartsolo.mid successfully.
# Downloaded Animal_Crossing_Save_Screen.mid successfully.
# Downloaded Glitzville1.mid successfully.
# Downloaded FF4.mid successfully.
# Downloaded Medieval.mid successfully.
# Downloaded vicecity-piano.mid successfully.
# Downloaded Investigation_Cornered.mid successfully.
# Downloaded FFVII_BATTLE.mid successfully.
# Downloaded odin_hope_follow_holy_war.mid successfully.
# Downloaded lom_gatosolo.mid successfully.
# Downloaded Lhasa%28piano%29.mid successfully.
# Downloaded wheel.mid successfully.
# Downloaded chase_theme.mid successfully.
# Downloaded Mother_Introduction.mid successfully.
# Downloaded thenightmarebegins.mid successfully.
# Downloaded battlerock.mid successfully.
# Downloaded Ff7-Cinco.mid successfully.
# Downloaded BFBB_Spongebob_Neighborhood.mid successfully.
# Downloaded Heres_some_weapons.mid successfully.
# Downloaded Yamato_Region.mid successfully.
# Downloaded HousePiano.mid successfully.
# Downloaded FFX_-_Ending_Theme_%28Piano_Version%29_-_by_Angel_FF.mid successfully.
# Downloaded IsleOHags_Cauldron_Keep_Piano.mid successfully.
# Downloaded Z23.mid successfully.
# Downloaded Gold_Silver_Rival_Battle.mid successfully.
# Downloaded ForestTemple.mid successfully.
# Downloaded WindsPlains.mid successfully.
# Downloaded secretotforest-piano.mid successfully.
# Downloaded ff4pclov.mid successfully.
# Downloaded BrokenShards.mid successfully.
# Downloaded Eternal_Harvest.mid successfully.
# Downloaded lom_nostasolo2.mid successfully.
# Downloaded FF6epitaph_piano.mid successfully.
# Downloaded metalman.mid successfully.
# Downloaded blizzard.mid successfully.
# Downloaded ultros.mid successfully.
# Downloaded TLOZOOS_Din_Kio_8.mid successfully.
# Downloaded BT_Witchyworld_Piano.mid successfully.
# Downloaded act_raiser-north_wall.mid successfully.
# Downloaded DKC_Map2.mid successfully.
# Downloaded telengaurd_piano.mid successfully.
# Downloaded FP.mid successfully.
# Downloaded dkcddtwrinklesolo.mid successfully.
# Downloaded SMW_Forest.mid successfully.
# Downloaded cbfdbatula.mid successfully.
# Downloaded Egadd.mid successfully.
# Downloaded SandgemTownDay.mid successfully.
# Downloaded Rugged_Ridge.mid successfully.
# Downloaded ghostgoblin.mid successfully.
# Downloaded Suikoden2-cookoff.mid successfully.
# Downloaded Legend_of_Mana_Southern_City_Polporta.mid successfully.
# Downloaded gerudo.mid successfully.
# Downloaded Zelda.mid successfully.
# Downloaded Meta_Knights_Revenge.mid successfully.
# Downloaded buoybase.mid successfully.
# Downloaded monkeyball.mid successfully.
# Downloaded 5_-_A_prayer_to_Zeus.mid successfully.
# Downloaded GE64-statsolo.mid successfully.
# Downloaded dkl-templesolo.mid successfully.
# Downloaded Sad%28piano%29.mid successfully.
# Downloaded cosmo.mid successfully.
# Downloaded TjsS2OP.mid successfully.
# Downloaded anxiousheartpiano.mid successfully.
# Downloaded Olympus_no_tatakai_piano.mid successfully.
# Downloaded Gestation.mid successfully.
# Downloaded dreamy.mid successfully.
# Downloaded Sand_Canyon_3.mid successfully.
# Downloaded continue.mid successfully.
# Downloaded Super_Mario_Lands1.mid successfully.
# Downloaded plant.mid successfully.
# Downloaded GE64-runwaysolo.mid successfully.
# Downloaded SSBM_StarFox_Medley.mid successfully.
# Downloaded hyrule_field.mid successfully.
# Downloaded dayafter.mid successfully.
# Downloaded remniscence.mid successfully.
# Downloaded GV.mid successfully.
# Downloaded TVP.mid successfully.
# Downloaded simpleandclean.mid successfully.
# Downloaded relmstheme-piano.mid successfully.
# Downloaded columns-clothos-midi.mid successfully.
# Downloaded ToMyLove-Piano.mid successfully.
# Downloaded Battle_LoZWW.mid successfully.
# Downloaded SMRPG_Intro1.mid successfully.
# Downloaded sa_vs_wait_piano.mid successfully.
# Downloaded dk_title.mid successfully.
# Downloaded Ctoceanp.mid successfully.
# Downloaded BlueStone_MillenialFair.mid successfully.
# Downloaded Forsaken_Fortress_Invasion_2_Piano.mid successfully.
# Downloaded corridor.mid successfully.
# Downloaded Level1piano.mid successfully.
# Downloaded BlueStone_LastDungeon.mid successfully.
# Downloaded Emerald_Hill_Piano.mid successfully.
# Downloaded BT_Dragon_Bosses_Piano_100.mid successfully.
# Downloaded Royalty_piano_.mid successfully.
# Downloaded Suikoden2-opbgm.mid successfully.
# Downloaded SMLPiano.mid successfully.
# Downloaded sm1bwin.mid successfully.
# Downloaded SnakeMan_Stage.mid successfully.
# Downloaded Super_Mario_Kart_Menu.mid successfully.
# Downloaded Z8.mid successfully.
# Downloaded SelectAFilePiano.mid successfully.
# Downloaded LOZOOTmedley.mid successfully.
# Downloaded songofhealing.mid successfully.
# Downloaded Fyw_piano.mid successfully.
# Downloaded dkcddtmillsolo2.mid successfully.
# Downloaded radicaldreamers-piano.mid successfully.
# Downloaded wings.mid successfully.
# Downloaded TetrisNameAS.mid successfully.
# Downloaded sth2racere.mid successfully.
# Downloaded Final_Fantasy_7_-_Judgement_Day_Piano.mid successfully.
# Downloaded 06crashman.mid successfully.
# Downloaded floating_in_the_air.mid successfully.
# Downloaded EyesOnMePiano.mid successfully.
# Downloaded Fountain_of_Dreams_Piano_Remix.mid successfully.
# Downloaded Motzhand_Quickie.mid successfully.
# Downloaded runescape_lumbridge_piano.mid successfully.
# Downloaded Serenade.mid successfully.
# Downloaded 1.mid successfully.
# Downloaded BT_Spiral_Mountain_Piano.mid successfully.
# Downloaded norKEM.mid successfully.
# Downloaded BlueStone_GreenGreensHard.mid successfully.
# Downloaded ahead_on_our_way_piano.mid successfully.
# Downloaded Aion_Wings_Of_The_Knight.mid successfully.
# Downloaded 05airman.mid successfully.
# Downloaded chargeman.mid successfully.
# Downloaded BK_FP_Piano.mid successfully.
# Downloaded Metal_Gear_Solid_2-_Piano.mid successfully.
# Downloaded CastleVania_-_StageClear.mid successfully.
# Downloaded lom_seasolo.mid successfully.
# Downloaded cpt_clawswamp.mid successfully.
# Downloaded Cohens_Masterpiece.mid successfully.
# Downloaded 7Church.mid successfully.
# Downloaded Aion_Forgotten_Sorrow.mid successfully.
# Downloaded Dr_Toungues_Castle.mid successfully.
# Downloaded Windfall_Island.mid successfully.
# Downloaded Ff4-BattleLust.mid successfully.
# Downloaded 5_and_6.mid successfully.
# Downloaded 7.mid successfully.
# Downloaded SMW_Ending.mid successfully.
# Downloaded donuts.mid successfully.
# Downloaded Route_42.mid successfully.
# Downloaded SotC_The_Opened_Way.mid successfully.
# Downloaded SMW_Title.mid successfully.
# Downloaded lostwoods.mid successfully.
# Downloaded mining.mid successfully.
# Downloaded 2_-_A_brave_Warrior.mid successfully.
# Downloaded Ghosts_of_the_Past.mid successfully.
# Downloaded monster.mid successfully.
# Downloaded ShipofRegretandSleep.mid successfully.
# Downloaded chocomountainpiano.mid successfully.
# Downloaded Kingdom_Hearts_Traverse_Town.mid successfully.
# Downloaded easykamesolo.mid successfully.
# Downloaded TheSims_TheNeighborhood_Piano.mid successfully.
# Downloaded Ff7-Jenova_Absolute.mid successfully.
# Downloaded smb3-airship_piano.mid successfully.
# Downloaded dkl.mid successfully.
# Downloaded z64_market_piano.mid successfully.
# Downloaded pkmncentre.mid successfully.
# Downloaded Spirit_of_Fire.mid successfully.
# Downloaded traitor.mid successfully.
# Downloaded Wonderboy_3_Melody_Piano.mid successfully.
# Downloaded MegaManVI_Final_boss_piano_version_Eb-major.mid successfully.
# Downloaded MetaRidley.mid successfully.
# Downloaded argonia.mid successfully.
# Downloaded JabuJabuBelly.mid successfully.
# Downloaded lom_drseedsolo.mid successfully.
# Downloaded Goron.mid successfully.
# Downloaded rufus.mid successfully.
# Downloaded hmBTN-springsolo.mid successfully.
# Downloaded Circus_Charlie1.mid successfully.
# Downloaded Kokiri_Forest.mid successfully.
# Downloaded lom_luminasolo.mid successfully.
# Downloaded bloody.mid successfully.
# Downloaded BaWC.mid successfully.
# Downloaded MajMas-WAGONSOLO.mid successfully.
# Downloaded SotC_The_Farthes_Land.mid successfully.
# Downloaded Mother_Queen_Marys_Castle.mid successfully.
# Downloaded SMB3_Toad.mid successfully.
# Downloaded FF3_Third_Phase_Final_%28Piano%29.mid successfully.
# Downloaded stage1.mid successfully.
# Downloaded clockwork_tower_piano_only_2.mid successfully.
# Downloaded Hm64wint.mid successfully.
# Downloaded Theme_A_-_Tetris.mid successfully.
# Downloaded BKigloosolo.mid successfully.
# Downloaded mgs_main_theme.mid successfully.
# Downloaded yswars.mid successfully.
# Downloaded islands.mid successfully.
# Downloaded dialga.mid successfully.
# Downloaded isle_o_rags.mid successfully.
# Downloaded Z-OoA_LynnaCity-PianoOnly.mid successfully.
# Downloaded snakeman.mid successfully.
# Downloaded SMB3_Ending_Intro.mid successfully.
# Downloaded Mario_3.mid successfully.
# Downloaded SMB1OW.mid successfully.
# Downloaded eyelids.mid successfully.
# Downloaded irish_touch.mid successfully.
# Downloaded LostPaintingPiano.mid successfully.
# Downloaded TempleOfTimePiano.mid successfully.
# Downloaded Fencing_Instruction_Piano.mid successfully.
# Downloaded MajMas-ALIENSOLO.mid successfully.
# Downloaded Z219.mid successfully.
# Downloaded ff4-airship.mid successfully.
# Downloaded Wood_Carving_Partita.mid successfully.
# Downloaded braska.mid successfully.
# Downloaded rondo.mid successfully.
# Downloaded piano.mid successfully.
# Downloaded mutsusolo.mid successfully.
# Downloaded Sonic_the_Hedgehog_3_-_Balloon_Park_Competiton_Course.mid successfully.
# Downloaded gourmetsolo.mid successfully.
# Downloaded great_war.mid successfully.
# Downloaded GatheringStarsInTheNightSky.mid successfully.
# Downloaded OceanicMuseum.mid successfully.
# Downloaded mystthemepiano.mid successfully.
# Downloaded lightwld.mid successfully.
# Downloaded hyrule-castle-town-in-c-major_piano-duet.mid successfully.
# Downloaded BKbubblesolo.mid successfully.
# Downloaded Chrono_Trigger_1000_ad.mid successfully.
# Downloaded SMB3_Overworld_2.mid successfully.
# Downloaded midna.mid successfully.
# Downloaded iced_land_piano_only.mid successfully.
# Downloaded columns-atropos.mid successfully.
# Downloaded dkl-constructsolo.mid successfully.
# Downloaded TwinleafTownDay.mid successfully.
# Downloaded Medley_M64.mid successfully.
# Downloaded Finalfantasy6fanfarecomplete.mid successfully.
# Downloaded clocktower.mid successfully.
# Downloaded good_egg_galaxy_piano.mid successfully.
# Downloaded DOS.mid successfully.
# Downloaded waltz_de_choco.mid successfully.
# Downloaded Ganon.mid successfully.
# Downloaded TOMBremix.mid successfully.
# Downloaded poktcg-mainsolo.mid successfully.
# Downloaded sobf.mid successfully.
# Downloaded Portal_-_Still_Alive.mid successfully.
# Downloaded Pianotris.mid successfully.
# Downloaded lom_make.mid successfully.
# Downloaded Puzzles_Abound.mid successfully.
# Downloaded da_smwathletic-piano.mid successfully.
# Downloaded 4.mid successfully.
# Downloaded dkcddtcapricesolo.mid successfully.
# Downloaded rozen-maiden-kodoku-na-kokoro.mid successfully.
# Downloaded Spelunkerpiano.mid successfully.
# Downloaded Guilty_Gear_XX__Last_Boss__The_Midnight_Carnival.mid successfully.
# Downloaded dkcddtBADparade.mid successfully.
# Downloaded TheWoundedShallAdvanceIntoTheLight.mid successfully.
# Downloaded Grandia_Title_Piano_dw.mid successfully.
# Downloaded dontbeafraid.mid successfully.
# Downloaded 04woodman.mid successfully.
# Downloaded xion.mid successfully.
# Downloaded Mother_Youngtown.mid successfully.
# Downloaded sth2oil.mid successfully.
# Downloaded CKFF6DBp.mid successfully.
# Downloaded EAGLE.mid successfully.
# Downloaded cchitcat.mid successfully.
# Downloaded LoZTP_-_Fyre_Piano_-_By_DaDude.mid successfully.
# Downloaded Zelda_Level9.mid successfully.
# Downloaded path_of_repentance.mid successfully.
# Downloaded RedKnight.mid successfully.
# Downloaded dparture.mid successfully.
# Downloaded thoughts.mid successfully.
# Downloaded zeldaoverworldgb.mid successfully.
# Downloaded Europe%28piano%29.mid successfully.
# Downloaded tim2.mid successfully.
# Downloaded wish.mid successfully.
# Downloaded ff7-mainmidi.mid successfully.
# Downloaded Ff7-One_Winged.mid successfully.
# Downloaded The_Sims_2_-_Simsation.mid successfully.
# Downloaded Finish_the_Fight.mid successfully.
# Downloaded AsaZanarkand.mid successfully.
# Downloaded Kanden_Fight.mid successfully.
# Downloaded goldsaucer.mid successfully.
# Downloaded roseofmay-piano.mid successfully.
# Downloaded BlueStone_MagiBattle.mid successfully.
# Downloaded kind_memories.mid successfully.
# Downloaded Glitzville.mid successfully.
# Downloaded Clock_Town_Day_1-Piano.mid successfully.
# Downloaded MajMas-NVRTSTON.mid successfully.
# Downloaded Raiden_Trad_Gallant_Tears.mid successfully.
# Downloaded dkcddt-wrinkle64SOLO.mid successfully.
# Downloaded route_1.mid successfully.
# Downloaded mystic-cave-zone-2-player.mid successfully.
# Downloaded ACDC_town_piano.mid successfully.
# Downloaded BiancoHills.mid successfully.
# Downloaded OTD5YA.mid successfully.
# Downloaded Rydia_pc.mid successfully.
# Downloaded antipyretic.mid successfully.
# Downloaded strange_tale.mid successfully.
# Downloaded lom_mysticgsolo.mid successfully.
# Downloaded Zelda_GameOver.mid successfully.
# Downloaded Outset_Island-1.mid successfully.
# Downloaded orasSoaringDayPiano.mid successfully.
# Downloaded 6_-_Orpheus%27_Journey.mid successfully.
# Downloaded 0fithos.mid successfully.
# Downloaded danceofgold-piano.mid successfully.
# Downloaded metroid_overworld_piano.mid successfully.
# Downloaded WorldRunner.mid successfully.
# Downloaded balamb.mid successfully.
# Downloaded chemplnt.mid successfully.
# Downloaded Sonic_the_Hedgehog_Final_Zone.mid successfully.
# Downloaded FFIX_Piano.mid successfully.
# Downloaded Roxmas2.mid successfully.
# Downloaded Finalfantasy5gilgameshp.mid successfully.
# Downloaded StarFestival.mid successfully.
# Downloaded Pinna_Park.mid successfully.
# Downloaded SMW-castle-pno.mid successfully.
# Downloaded athena_lvl_2.mid successfully.
# Downloaded Mirrors_edge_piano_still_alive.mid successfully.
# Downloaded Super-Nintendo_Super-Mario-World_Ending.mid successfully.
# Downloaded cearleonpiano.mid successfully.
# Downloaded sth2skychase.mid successfully.
# Downloaded GE64-frigatesolo.mid successfully.
# Downloaded zelda_prelude_in_g.mid successfully.
# Downloaded Shadow_of_the_colossus_-_prologue.mid successfully.
# Downloaded command_melody_lozww_piano.mid successfully.
# Downloaded Halo_Maine_Theme_Extended_Maw_Version.mid successfully.
# Downloaded VincentPiano.mid successfully.
# Downloaded nienMED.mid successfully.
# Downloaded lom_ctysolo.mid successfully.
# Downloaded SMB2_Overworld.mid successfully.
# Downloaded sth3launch.mid successfully.
# Downloaded weapon.mid successfully.
# Downloaded Mother_Podunk.mid successfully.
# Downloaded In_Zanarkand.mid successfully.
# Downloaded h.mid successfully.
# Downloaded STIIZodaBattleAS.mid successfully.
# Downloaded BlueStone_Magicant.mid successfully.
# Downloaded Midna_Theme.mid successfully.
# Downloaded WGA.mid successfully.
# Downloaded Back_Fire.mid successfully.
# Downloaded z_aeristhemepiano.mid successfully.
# Downloaded Piano__Ico__Beginning.mid successfully.
# Downloaded AdventureOfLink_Bossbattle.mid successfully.
# Downloaded ff2japantown.mid successfully.
# Downloaded dino_riki_1.mid successfully.
# Downloaded B-K_RBBAquatic_Piano.mid successfully.
# Downloaded simc-toensolo.mid successfully.
# Downloaded lom_pastoralsolo.mid successfully.
# Downloaded Piano_Only_Hyrule_Temple.mid successfully.
# Downloaded intro.mid successfully.
# Downloaded magmail.mid successfully.
# Downloaded hyrule.mid successfully.
# Downloaded DKCDKQ-snakesolo.mid successfully.
# Downloaded The_Story_Is_Over.mid successfully.
# Downloaded BaldursGate-Safe_in_Beregost.mid successfully.
# Downloaded batman_megadrive_flugelheim_museum_piano.mid successfully.
# Downloaded KBB_-_Game_Over_Piano_Waltz.mid successfully.
# Downloaded ff4-town.mid successfully.
# Downloaded WWIntroPiano.mid successfully.
# Downloaded gravityman.mid successfully.
# Downloaded Oakvale.mid successfully.
# Downloaded Ed_Foley--BTFM_Simple.mid successfully.
# Downloaded BanjoKazooie.mid successfully.
# Downloaded Sarias_Song_piano.mid successfully.
# Downloaded Peril_piano.mid successfully.
# Downloaded odeofix.mid successfully.
# Downloaded ff7_ahead_on_our_way_piano_dw.mid successfully.
# Downloaded ff7themep.mid successfully.
# Downloaded darkman.mid successfully.
# Downloaded lom_jousolo.mid successfully.
# Downloaded Fierce_Battle_%28Piano%29.mid successfully.
# Downloaded ff4pcpro.mid successfully.
# Downloaded 5.mid successfully.
# Downloaded Set_Free_Piano.mid successfully.
# Downloaded final_fantasy_versus_13.mid successfully.
# Downloaded SMB1UW.mid successfully.
# Downloaded POGetUpAS.mid successfully.
# Downloaded darkwrld.mid successfully.
# Downloaded ff1battp.mid successfully.
# Downloaded ff4_piano_collections-main_theme.mid successfully.
# Downloaded Fiend_Battle_%28Piano%29.mid successfully.
# Downloaded Metal_Gear_Solid_2_-_Main_Theme.mid successfully.
# Downloaded HARMONY_PNO_CM.mid successfully.
# Downloaded Piano__Shadow_of_the_Colossus__The_Farthest_Land__2.mid successfully.
# Downloaded Obseravtory.mid successfully.
# Downloaded mumbofixed.mid successfully.
# Downloaded bubblep.mid successfully.
# Downloaded flashman.mid successfully.
# Downloaded Mario_Dies_Super_Mario_World.mid successfully.
# Downloaded ultimafro.mid successfully.
# Downloaded chugokusolo.mid successfully.
# Downloaded GE64-damsolo.mid successfully.
# Downloaded Metroid_Prime_Credits.mid successfully.
# Downloaded caitsith.mid successfully.
# Downloaded inverted_song_time_piano.mid successfully.
# Downloaded WONLAND.mid successfully.
# Downloaded ge64-RUNXSOLO.mid successfully.
# Downloaded Z42.mid successfully.
# Downloaded GameOverPiano.mid successfully.
# Downloaded tpirtsd-piano.mid successfully.
# Downloaded FinalDay_piano_.mid successfully.
# Downloaded plant_selection.mid successfully.
# Downloaded figaro.mid successfully.
# Downloaded LoZOoT_-_Prelude_of_Light_Piano_Only_-_By_DaDude.mid successfully.
# Downloaded ff4-fight1.mid successfully.
# Downloaded mushking.mid successfully.
# Downloaded MegaManVI_Final_boss_piano_version_C-major.mid successfully.
# Downloaded Route_12.mid successfully.
# Downloaded adventures_of_link-main_theme.mid successfully.
# Downloaded Mysterious_Bird_Attack_Piano.mid successfully.
# Downloaded electric_de_chocobo.mid successfully.
# Downloaded One_Winged_Angel_REBORN.mid successfully.
# Downloaded Pyramid_of_Fear.mid successfully.
# Downloaded whoareyou.mid successfully.
# Downloaded DKONG.mid successfully.
# Downloaded SMWk.mid successfully.
# Downloaded Fire_Emblem_SSBM_Piano.mid successfully.
# Downloaded Aion_The_Still_Sad_World.mid successfully.
# Downloaded lom_daedelsolo.mid successfully.
# Downloaded Theme_of_Tara.mid successfully.
# Downloaded redwings.mid successfully.
# Downloaded finalbosspiano.mid successfully.
# Downloaded Kirby_Triple_Deluxe_Boss_Piano.mid successfully.
# Downloaded O2_Final_Boss_-_Kirby_64.mid successfully.
# Downloaded TearoftheStars.mid successfully.
# Downloaded Forsaken_Fortress_Piano.mid successfully.
# Downloaded Europe(piano).mid successfully.
# Downloaded bomb.mid successfully.
# Downloaded CVAoS-Heart_of_Fire-piano.mid successfully.
# Downloaded Zelda2_Palace.mid successfully.
# Downloaded Hyrule_Castle_-_Zelda_A_Link_to_the_Past.mid successfully.
# Downloaded Cids.mid successfully.
# Downloaded 08heatman.mid successfully.
# Downloaded MajMas-MAIOSOLO.mid successfully.
# Downloaded Zelda_Overworld.mid successfully.
# Downloaded surf.mid successfully.
# Downloaded Here_comes_trouble_piano_V2.mid successfully.
# Downloaded sth2wing.mid successfully.
# Downloaded Title_2_midi.mid successfully.
# Downloaded Oppressed.mid successfully.
# Downloaded Midnas_Desperation_-_Arranged.mid successfully.
# Downloaded byakuyagensoutanPIANO.mid successfully.
# Downloaded smb-starman-piano.mid successfully.
# Downloaded SC_SNES_Budget_Piano_dw.mid successfully.
# Downloaded decisive.mid successfully.
# Downloaded GE64-cavernsolo.mid successfully.
# Downloaded FF8_Shuffle_or_boogie_pc.mid successfully.
# Downloaded dkl-cloudsolo.mid successfully.
# Downloaded Kingdom_Hearts_Dearly_Beloved.mid successfully.
# Downloaded Forsaken_Fortress_Invasion_Piano.mid successfully.
# Downloaded Aion_Death_Waltz.mid successfully.
# Downloaded BondsSeaFire.mid successfully.
# Downloaded basket.mid successfully.
# Downloaded GameCornerRag.mid successfully.
# Downloaded SML_W4.mid successfully.
# Downloaded centaur.mid successfully.
# Downloaded finalfantasy3japan_battlepiano.mid successfully.
# Downloaded Z9-2.mid successfully.
# Downloaded flowerbudsolo.mid successfully.
# Downloaded pkmnindigov1.mid successfully.
# Downloaded water.mid successfully.
# Downloaded burstman.mid successfully.
# Downloaded lom_dnovasolo.mid successfully.
# Downloaded Suikoden2-Kyaro.mid successfully.
# Downloaded magustheme-piano.mid successfully.
# Downloaded Windmill_Hut.mid successfully.
# Downloaded MKDD_-_Results_-_4th_or_Worse_-_Piano_Only_-_By_DaDude.mid successfully.
# Downloaded Tetris_Orchestrated_Transcribed.mid successfully.
# Downloaded SPM.mid successfully.
# Downloaded SMW-Donut.mid successfully.
# Downloaded Wind_Waker_Special.mid successfully.
# Downloaded Grassy_Path-piano.mid successfully.
# Downloaded Cossack_Citadel_Stage_3-4.mid successfully.
# Downloaded Route_36.mid successfully.
# Downloaded serenade_of_water-piano.mid successfully.
# Downloaded collets_theme.mid successfully.
# Downloaded DemonCastlePinnacle.mid successfully.
# Downloaded emerald.mid successfully.
# Downloaded yoshi17.mid successfully.
# Downloaded edc.mid successfully.
# Downloaded Animania.mid successfully.
# Downloaded JENOVA.mid successfully.
# Downloaded BanjoTooie.mid successfully.
# Downloaded ebsnowschool.mid successfully.
# Downloaded ge64-FaXSOLO.mid successfully.
# Downloaded Not_Tomorrow.mid successfully.
# Downloaded sandcan.mid successfully.
# Downloaded sonic3-icecap-frozentears.mid successfully.
# Downloaded mys-01.mid successfully.
# Downloaded Piano__Okami__Tribe_of_Heavenly_Gods.mid successfully.
# Downloaded BT_Dragon_Bosses_Piano.mid successfully.
# Downloaded dds2_hunting.mid successfully.
# Downloaded fortresscondor.mid successfully.
# Downloaded xb_kh_endworldbattle_p.mid successfully.
# Downloaded ff1deadp.mid successfully.
# Downloaded ssbstarfoxpiano.mid successfully.
# Downloaded Mother_Mt_Itoi.mid successfully.
# Downloaded tim1.mid successfully.
# Downloaded shenmue___u_could_have_knocked.mid successfully.
# Downloaded childrenplaying-piano.mid successfully.
# Downloaded goldmoon.mid successfully.
# Downloaded mmx5bossintropianoversion.mid successfully.
# Downloaded metroid_ending_piano.mid successfully.
# Downloaded slideshw.mid successfully.
# Downloaded CastlevaniaLevel1AS.mid successfully.
# Downloaded metroid_kraids_lair_piano.mid successfully.
# Downloaded Piano_Teehee_Vallry.mid successfully.
# Downloaded Dedede-piano.mid successfully.
# Downloaded cantinaband.mid successfully.
# Downloaded FFIII_Edgar_And_Sabin_Piano.mid successfully.
# Downloaded bcm.mid successfully.
# Downloaded Route_27.mid successfully.
# Downloaded ult5Stones.mid successfully.
# Downloaded kaeporagaebora.mid successfully.
# Downloaded Route_30.mid successfully.
# Downloaded Z-Infinity--.mid successfully.
# Downloaded TouchFuzzyGetDizzyPiano.mid successfully.
# Downloaded Mother_Bein_Friends.mid successfully.
# Downloaded athlete.mid successfully.
# Downloaded infants.mid successfully.
# Downloaded SMB2_Boss.mid successfully.
# Downloaded Embassy_Function_GM.mid successfully.
# Downloaded sacrifice3piano.mid successfully.
# Downloaded hymn.mid successfully.
# Downloaded Wind_Temple.mid successfully.
# Downloaded punch.mid successfully.
# Downloaded Etude_for_Ghosts.mid successfully.
# Downloaded FFIXQuMarshP.mid successfully.
# Downloaded summersolo.mid successfully.
# Downloaded Zelda_A_Link_Between_Worlds__-_Ra.mid successfully.
# Downloaded ff11_awakening_piano.mid successfully.
# Downloaded Life_Stream.mid successfully.
# Downloaded beast2.mid successfully.
# Downloaded SMB3_Battle.mid successfully.
# Downloaded SMB2_Character_Select.mid successfully.
# Downloaded Shademan.mid successfully.
# Downloaded MajMas-DPSOLO.mid successfully.
# Downloaded Mario_Sunshine_Delfino_Plaza_Theme.mid successfully.
# Downloaded Final_Fantasy_Matouyas_Cave_Piano.mid successfully.
# Downloaded Creation_piano_.mid successfully.
# Downloaded smbt.mid successfully.
# Downloaded ChargeMan.mid successfully.
# Downloaded Mine_Cart-piano.mid successfully.
# Downloaded silentlight-piano.mid successfully.
# Downloaded Piano__Shadow_of_the_Colossus__Prayer.mid successfully.
# Downloaded MidnaDesperation.mid successfully.
# Downloaded 1_-_The_Story_of_a_Lost_Love.mid successfully.
# Downloaded Mother_Twinkle_Elementary_School.mid successfully.
# Downloaded 9.mid successfully.
# Downloaded adventures_of_link-house.mid successfully.
# Downloaded lom_journeysolo.mid successfully.
# Downloaded faxoverworld.mid successfully.
# Downloaded HeroesOfMightAndMagic3-MainMenuPiano.mid successfully.
# Downloaded Black_Waltz.mid successfully.
# Downloaded Seiken_Densetsu_3_Decision_Bell.mid successfully.
# Downloaded Zelda_Labryinth.mid successfully.
# Downloaded hikaripiano.mid successfully.
# Downloaded gg2ingamemusic.mid successfully.
# Downloaded W2-Koopahari-v2.mid successfully.
# Downloaded dkcddt-ccalypsolo.mid successfully.
# Downloaded At_Zanarkand_Piano_Collection_%28Unofficial%29.mid successfully.
# Downloaded Suikoden2-nameselection.mid successfully.
# Downloaded CastlevaniaPOR-Hail_From_The_Past.mid successfully.
# Downloaded N-Gin.mid successfully.
# Downloaded cloudman.mid successfully.
# Downloaded magnet.mid successfully.
# Downloaded sunnymountsolo.mid successfully.
# Downloaded castle.mid successfully.
# Downloaded Music_Box_Clock.mid successfully.
# Downloaded Chillout.mid successfully.
# Downloaded poktcg-wgymsolo.mid successfully.
# Downloaded som-danger-pno.mid successfully.
# Downloaded BlueStone_DarkWorldDungeon.mid successfully.
# Downloaded circus_charlie_1_4.mid successfully.
# Downloaded DL6.mid successfully.
# Downloaded HighwindTakestotheSkies.mid successfully.
# Downloaded BlueStone_JibJig.mid successfully.
# Downloaded ff8-lfp.mid successfully.
# Downloaded Scrap_Brain_Jazz.mid successfully.
# Downloaded Bowsers_Theme.mid successfully.
# Downloaded leaving.mid successfully.
# Downloaded SotC_Memories.mid successfully.
# Downloaded dotHack_Loop2.mid successfully.
# Downloaded Final_Fantasy_9_Youre__Not_Alone.mid successfully.
# Downloaded AnotherGuldovePiano.mid successfully.
# Downloaded poktcg-duelsolo.mid successfully.
# Downloaded Hylianische_Steppe_Theme.mid successfully.
# Downloaded n64_f0x_sm01_piano.mid successfully.
# Downloaded venuslighthouse.mid successfully.
# Downloaded dkl-blimpsolo.mid successfully.
# Downloaded sth2oilARR.mid successfully.
# Downloaded sandy.mid successfully.
# Downloaded ETPV.mid successfully.
# Downloaded lom_dominasolo.mid successfully.
# Downloaded Kid_Icarus.mid successfully.
# Downloaded 8.mid successfully.
# Downloaded Farewell_Hyrule_King_pedal-added.mid successfully.
# Downloaded bloodytears.mid successfully.
# Downloaded skull2.mid successfully.
# Downloaded Planet_Venom.mid successfully.
# Downloaded HISSATSU_Jamba.mid successfully.
# Downloaded ordon.mid successfully.
# Downloaded Route_29.mid successfully.
# Downloaded EGG_Station_Piano.mid successfully.
# Downloaded MMX5TitleTheme-Piano.mid successfully.
# Downloaded SMB3_Ending_Loop.mid successfully.
# Downloaded ff6shap.mid successfully.
# Downloaded tifap.mid successfully.
# Downloaded wendysolo.mid successfully.
# Downloaded DKCDKQ-bayousolo.mid successfully.
# Downloaded burstmn2.mid successfully.
# Downloaded MM3PasswordAS.mid successfully.
# Downloaded 3_-_Athene_Sonata.mid successfully.
# Downloaded Suteki_Da_Ne_%28Piano_Version%29.mid successfully.
# Downloaded FireEmblemTheme1_1.mid successfully.
# Downloaded 4_-_3_Magic_Hearts.mid successfully.
# Downloaded MZM_-_Title_Screen_-_Piano_Only_-_By_DaDude.mid successfully.
# Downloaded YMED.mid successfully.
# Downloaded Fountain_of_Dreams_Solo_Piano.mid successfully.
# Downloaded spirit_duet_piano.mid successfully.
# Downloaded wormspiano.mid successfully.
# Downloaded Aion_Tower_Of_Eternity.mid successfully.
# Downloaded SMW2_Athletic.mid successfully.
# Downloaded Piano__Star_Fox__Space_Armada.mid successfully.
# Downloaded AshleyThemePianoOnly.mid successfully.
# Downloaded cc_another_aruni_piano.mid successfully.
# Downloaded ICECAP.mid successfully.
# Downloaded Meridian_Dance_piano.mid successfully.
# Downloaded earthwormjim_3d-poultrygeist.mid successfully.
# Downloaded StolenTreasure.mid successfully.
# Downloaded Ridley-p.mid successfully.
# Downloaded KingdomHearts_PiratesGigue.mid successfully.
# Downloaded BlueStone_Ocean.mid successfully.
# Downloaded GyakutenSistersBalladev11.mid successfully.
# Downloaded princesstomato-maintheme.mid successfully.
# Downloaded ChronoTrigger.mid successfully.
# Downloaded robotnik.mid successfully.
# Downloaded fairy.mid successfully.
# Downloaded MM2-Wily_1-Piano-V_2.mid successfully.
# Downloaded spirit_night.mid successfully.
# Downloaded Zombie_Panic.mid successfully.
# Downloaded SaveCottagespiano.mid successfully.
# Downloaded beyondthe.mid successfully.
# Downloaded Max_Payne_Theme.mid successfully.
# Downloaded finalpiano.mid successfully.
# Downloaded SGBA3_Snow_Act2_V1_1_Piano.mid successfully.
# Downloaded MP_Item_Acquired_-_Piano_Only_-_By_DaDude.mid successfully.
# Downloaded Suikoden2-NinjaVillage.mid successfully.
# Downloaded Rachel_piano.mid successfully.
# Downloaded Gothic-MainTheme.mid successfully.
# Downloaded Aion_Song_of_Moonlight.mid successfully.
# Downloaded MP_Artifact_-_Piano_Only_-_By_DaDude.mid successfully.
# Downloaded dkcddtjanglebesolo.mid successfully.
# Downloaded GS5_The_Light_Moaning_In_The_Darkness.mid successfully.
# Downloaded brinstar.mid successfully.
# Downloaded 3.mid successfully.
# Downloaded bofard.mid successfully.
# Downloaded poktcg-pausolo.mid successfully.
# Downloaded SMB3_Boss.mid successfully.
# Downloaded s3db-diamond1.mid successfully.
# Downloaded 02quickman.mid successfully.
# Downloaded SSBB_PitUnderWorld.mid successfully.
# Downloaded MMX2Xhunter_v11.mid successfully.
# Downloaded GanonsCastle_LoZWW.mid successfully.
# Downloaded Surfing.mid successfully.
# Downloaded Bloody_Tears_Piano.mid successfully.
# Downloaded final_fantasy_battle_medley.mid successfully.
# Downloaded links_awakening_credits-piano.mid successfully.
# Downloaded casinooo.mid successfully.
# Downloaded DKCDKQ-krooksolo.mid successfully.
# Downloaded pkelite4.mid successfully.
# Downloaded ghosttoys.mid successfully.
# Downloaded Piano__Metal_Gear_Solid_2__Who_Am_I_Really.mid successfully.
# Downloaded MajMas-NORMSTON.mid successfully.
# Downloaded WL2-BballBoss-Piano.mid successfully.
# Downloaded mkingdom.mid successfully.
# Downloaded Space_Junk_Galaxy.mid successfully.
# Downloaded SON1TITLE.mid successfully.
# Downloaded elecman_piano.mid successfully.
# Downloaded costadsol.mid successfully.
# Downloaded ViviinAlexandria.mid successfully.
# Downloaded trailblood.mid successfully.
# Downloaded Bicycle_Theme.mid successfully.
# Downloaded sub_c.mid successfully.
# Downloaded Route_1.mid successfully.
# Downloaded Goldeneye_-_Finish_the_job_James_If_you_can_-_By_DaDude_-_Piano_Only.mid successfully.
# Downloaded KokoroPianoVersion.mid successfully.
# Downloaded BCCMatchPiano.mid successfully.
# Downloaded Route_38.mid successfully.
# Downloaded smb2main.mid successfully.
# Downloaded DKCDKQ-lavasolo.mid successfully.
# Downloaded monkey_ball_world_2.mid successfully.
# Downloaded Sabers_Edge_pf.mid successfully.
# Downloaded rose_ghost.mid successfully.
# Downloaded bouche_verdanturf_piano.mid successfully.
# Downloaded Dire_Dire_Docks_SM64.mid successfully.
# Downloaded HeSangOfFeelingPiano.mid successfully.
# Downloaded galaxy_man_piano.mid successfully.
# Downloaded dkl-bosssolo.mid successfully.
